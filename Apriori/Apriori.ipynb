# %% [markdown]
# # Implementing Apriori algorithm in Python
#
# # Example 1 Constructing Rules from Census Dataset Introduction

# %% [markdown]
# Data source: https://archive.ics.uci.edu/dataset/20/census+income

# %%
# !pip install ucimlrepo
# Out:
# ...
#   Obtaining dependency information for ucimlrepo from https://files.pythonhosted.org/packages/3b/07/1252560194df2b4fad1cb3c46081b948331c63eb1bb0b97620d508d12a53/ucimlrepo-0.0.7-py3-none-any.whl.metadata
# ...

# %%
# importing module
import pandas as pd
import numpy as np
from ucimlrepo import fetch_ucirepo

# %%
census_income = fetch_ucirepo(id=20) 
census_income.metadata

# %%
df = pd.read_csv("https://archive.ics.uci.edu/static/public/20/data.csv")
df.head(10)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
# 7   52  Self-emp-not-inc  209642    HS-grad              9
# 8   31           Private   45781    Masters             14
# 9   42           Private  159449  Bachelors             13
#
#           marital-status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %% [markdown]
# The census dataset provided in a CSV file consists of the attributes `age`, `sex`, `education`, `native-country`, `race`, `marital-status`, `workclass`, `occupation`, `hours-per-week`, `income`, `capital gain`, and `capital-loss`. The CSV file `census.csv` contains exactly 30162 rows and each row contains exactly 12 comma-separated values in the form attribute=value.
#
# First ten rows from `census.csv` Use this data to find patterns which would help make important data-driven decisions. For example, using the 10 lines above as input, we can find the following patterns that identify the groups with **no capital gain or loss**:
#
# * There are 7 people with (capital gain=0, capital-loss=0)
# * There are 5 people with (native-country=United States, capital- gain=0, capital-loss=0)
# * There are 5 people with (native-country United States, capital- gain=0)
# * There are 8 people with (native-country=United States, capital- loss=0)
#
# The **support** of the set of attributes is defined as the ratio of "total number of records with the given attributes" to "total number of records in the dataset". For example,
#
# * The support of (capital-gain=0 capital-lass=0) is 7/10 = 0.7
# * The support of (native-country = United States, capital-gain=0, capital-loss=0) is 5/10 = 0.5
# * The support of (native-country = United States, capital-gain=0) is 5/10 = 0.5
# * The support of (native-country = United States, capital-loss = 0) ls 8/10 = 0.8
#
# We can now derive some rules X => Y, where X and Y describe the attributes set. The **confidence** of the rule is defined as the ratio of "total number of records with the given unique attributes in X and Y" to "total number of records with the given attributes in X”, i.e., the ratio of "support of X U Y" to "support of X". For example:
#
# * The confidence of the rule (native-country=United States, capital-gain=0) => (capital-loss=0) is 0.5/0.5 = 1.0
# * The confidence of the rule (native-country=United States, capital-loss=0) => (capital-gain=0) is 0.5/0.8 = 0.625
# * The confidence of the rule (capital-gain=None.capital-loss=0) => (native-country=United States) is 0.5/0.7 = 0.7142857
#
# #### Task
#
# Rearrange the given set of rules X => Y in descending order of **confidence**. It is guaranteed that no two rules have the same confidence. Also, the support of the attributes sets X and Y in each of the rules is greater than or equal to 0.3.
#
# #### Function Description
#
# Complete the *arrangingRules* function in the editor below. The function must return a string array of the rules in descending order of confidence.
#
# *arrangingRules* has the following parameter(s):
#
# rules: an array of rules strings
#
# #### Constraints
#
# * 1 <= total number of rules <= 100
# * It is guaranteed that no two rules have the same confidence.
# * It is guaranteed that the support of the attributes sets X and Y in each of the rules is greater than or equal to 0.3.
#
# #### Input Format for Custom Testing
#
# Input from stdin will be processed as follows and passed to the function.
#
# The first line contains an integer *n*, the size of the string array *rules*.
#
# Each of the next *n* lines contains a *rule*.
#
# #### Sample Case 0
# Sample input:
# 3
# {native-country=United-States, capital-gain=0} => {capital-loss=0}
# {capital-gain=0, capital-loss=0} => {native-country=United-States}
# {native-country=United-States, capital-loss=0} => {capital-gain=0}
#
# Sample output:
# {native-country=United-States, capital-gain=0} => {capital-loss=0}
# {native-country=United-States, capital-loss=0} => {capital-gain=0}
# {capital-gain=0, capital-loss=0} => {native-country=United-States}
#
# Explanation:
# We sort the given array in descending order of confidence:
# * The confidence of the rule {native-country=United-States, capital-gain=0} => {capital-loss=0} is 0.7896/0.8336 = 0.9471465
# * The confidence of the rule {native-country=United-States, capital-loss=0} => {capital-gain=0} is 0.7896/0.8678 = 0.9098758
# * The confidence of the rule {capital-gain=0, capital-loss=0} => {native-country=United-States} is 0.7896/0.86854 = 0.90911

# %%
data = df.head(10)[['capital-gain', 'capital-loss', 'native-country']]
data
# Out:
#    capital-gain  capital-loss native-country
# 0          2174             0  United-States
# 1             0             0  United-States
# 2             0             0  United-States
# 3             0             0  United-States
# 4             0             0           Cuba
# 5             0             0  United-States
# 6             0             0        Jamaica
# 7             0             0  United-States
# 8         14084             0  United-States
# 9          5178             0  United-States

# %%
def remove_curved_brackets(attributes_str):
    for curved_sign in ["{", "}"]:
        attributes_str = attributes_str.strip(curved_sign)
    return attributes_str

def get_key_value(kv_str):
    k, v = kv_str.split("=")
    if v == '0':
        v = int(v)
    return k, v

def arrangingRules(rules):
    num_rules = rules[0]
    # get attributes
    attributes = []
    for i in range(num_rules):
        rule = rules[i+1]
        X, Y = rule.split(" => ")
        X = remove_curved_brackets(X)
        Y = remove_curved_brackets(Y)
        X1, X2 = X.split(", ")
        attributes.append({"X1": X1, "X2": X2, "Y": Y})
    print(attributes)

    # calculate confidence
    # no need to calculate single 
    base_num = data.shape[0]
    confidence_list = []
    for rule in attributes: # rule == {'X1': 'native-country=United-States', 'X2': 'capital-gain=0', 'Y': 'capital-loss=0'}
        X1k, X1v = get_key_value(rule['X1'])
        X2k, X2v = get_key_value(rule['X2'])
        Yk, Yv = get_key_value(rule['Y'])
        X_count_num = data[(data[X1k] == X1v) & (data[X2k] == X2v)].shape[0]
        XY_count_num = data[(data[X1k] == X1v) & (data[X2k] == X2v) & (data[Yk] == Yv)].shape[0]
        support_X = X_count_num / base_num
        support_XY = XY_count_num / base_num
        print(support_XY, support_X)
        confidence = support_XY / support_X
        confidence_list.append(confidence)
    
    # output
    confidence_dict = {}
    for i in range(num_rules):
        confidence_dict[rules[i+1]] = confidence_list[i]
    
    result = sorted(confidence_dict, key=confidence_dict.get, reverse=True)


    return result

rules = [3, 
    "{native-country=United-States, capital-gain=0} => {capital-loss=0}",
    "{capital-gain=0, capital-loss=0} => {native-country=United-States}",
    "{native-country=United-States, capital-loss=0} => {capital-gain=0}"
]
result = arrangingRules(rules)
print("Result = ", result)
# Out:
# [{'X1': 'native-country=United-States', 'X2': 'capital-gain=0', 'Y': 'capital-loss=0'}, {'X1': 'capital-gain=0', 'X2': 'capital-loss=0', 'Y': 'native-country=United-States'}, {'X1': 'native-country=United-States', 'X2': 'capital-loss=0', 'Y': 'capital-gain=0'}]
# 0.5 0.5
# 0.5 0.7
# 0.5 0.8
# Result =  ['{native-country=United-States, capital-gain=0} => {capital-loss=0}', '{capital-gain=0, capital-loss=0} => {native-country=United-States}', '{native-country=United-States, capital-loss=0} => {capital-gain=0}']

# %%
# Define the dictionary
rule_confidence = {
    "{native-country=United-States, capital-gain=0} => {capital-loss=0}": 1,
    "{capital-gain=0, capital-loss=0} => {native-country=United-States}": 0.987,
    "{native-country=United-States, capital-loss=0} => {capital-gain=0}": 1
}

# Sort the dictionary by value in descending order and get the keys
sorted_keys = sorted(rule_confidence, key=rule_confidence.get, reverse=True)
print(type(sorted_keys))
# Print the sorted keys
for key in sorted_keys:
    print(key)
# Out:
# <class 'list'>
# {native-country=United-States, capital-gain=0} => {capital-loss=0}
# {native-country=United-States, capital-loss=0} => {capital-gain=0}
# {capital-gain=0, capital-loss=0} => {native-country=United-States}

# %%
sorted_keys
# Out:
# ['{native-country=United-States, capital-gain=0} => {capital-loss=0}',
#  '{native-country=United-States, capital-loss=0} => {capital-gain=0}',
#  '{capital-gain=0, capital-loss=0} => {native-country=United-States}']

# %% [markdown]
# # Example 2
#
# https://www.geeksforgeeks.org/implementing-apriori-algorithm-in-python/

# %% [markdown]
# Import dataset

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
online_retail = fetch_ucirepo(id=352) 
  
# data (as pandas dataframes) 
X = online_retail.data.features 
y = online_retail.data.targets 
  
# metadata 
print(online_retail.metadata) 
  
# variable information 
print(online_retail.variables)
# Out:
# {'uci_id': 352, 'name': 'Online Retail', 'repository_url': 'https://archive.ics.uci.edu/dataset/352/online+retail', 'data_url': 'https://archive.ics.uci.edu/static/public/352/data.csv', 'abstract': 'This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.', 'area': 'Business', 'tasks': ['Classification', 'Clustering'], 'characteristics': ['Multivariate', 'Sequential', 'Time-Series'], 'num_instances': 541909, 'num_features': 6, 'feature_types': ['Integer', 'Real'], 'demographics': [], 'target_col': None, 'index_col': ['InvoiceNo', 'StockCode'], 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2015, 'last_updated': 'Fri Jan 05 2024', 'dataset_doi': '10.24432/C5BW33', 'creators': ['Daqing Chen'], 'intro_paper': {'title': 'Data mining for the online retail industry: A case study of RFM model-based customer segmentation using data mining', 'a
# ...

# %%
import numpy as np 
import pandas as pd 
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv("https://archive.ics.uci.edu/static/public/352/data.csv")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
df['InvoiceNo'].unique()
# Out:
# array(['536365', '536366', '536367', ..., '581585', '581586', '581587'],
#       dtype=object)

# %%
df[df['InvoiceNo'].str.contains('C')]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df['Description'] = df['Description'].str.strip()
df = df.dropna(axis=0, subset=['InvoiceNo'])
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
df.shape
# Out:
# (532621, 8)

# %% [markdown]
# ## Splitting the data according to the region of transaction

# %%
df[df['Country'] == "France"]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727         ALARM CLOCK BAKELIKE RED        24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                  STARS GIFT TAPE        24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899      CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254     CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138     BAKING SET 9 PIECE RETROSPOT         3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 26       12/1/2010 8:45       3.75     12583.0  France
# ...

# %%
df[df['Country'] == "France"].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().reset_index()
# Out:
#      InvoiceNo                      Description  Quantity
# 0       536370       ALARM CLOCK BAKELIKE GREEN        12
# 1       536370        ALARM CLOCK BAKELIKE PINK        24
# 2       536370         ALARM CLOCK BAKELIKE RED        24
# 3       536370  CHARLOTTE BAG DOLLY GIRL DESIGN        20
# 4       536370          CIRCUS PARADE LUNCH BOX        24
# ...        ...                              ...       ...
# 8367    581587          CIRCUS PARADE LUNCH BOX        12
# 8368    581587      PACK OF 20 SPACEBOY NAPKINS        12
# 8369    581587    PLASTERS IN TIN CIRCUS PARADE        12
# 8370    581587        PLASTERS IN TIN STRONGMAN        12
# 8371    581587               SPACEBOY LUNCH BOX        12
#
# [8372 rows x 3 columns]

# %%
df[df['Country'] == "France"].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index()
# Out:
# Description InvoiceNo  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# 0              536370                     NaN                         NaN
# 1              536852                     NaN                         NaN
# 2              536974                     NaN                         NaN
# 3              537065                     NaN                         NaN
# 4              537463                     NaN                         NaN
# ..                ...                     ...                         ...
# 387            580986                     NaN                         NaN
# 388            581001                     NaN                         NaN
# 389            581171                     NaN                         NaN
# 390            581279                     NaN                         NaN
# 391            581587                     NaN                         NaN
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# ...

# %%
basket_France = df[df['Country'] == "France"].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')
basket_UK = df[df['Country'] == "United Kindom"].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')
basket_Por = df[df['Country'] == "portugal"].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')
basket_Sweden = df[df['Country'] == "Sewden"].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')

# %%
basket_France.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# ...

# %% [markdown]
# # Hot encoding

# %%
def hot_encode(x):
    if (x <= 0):
        return 0
    if (x >= 1):
        return 1

# %%
# Encoding the datasets 
basket_encoded = basket_France.applymap(hot_encode) 
basket_France = basket_encoded 
  
basket_encoded = basket_UK.applymap(hot_encode) 
basket_UK = basket_encoded 
  
basket_encoded = basket_Por.applymap(hot_encode) 
basket_Por = basket_encoded 
  
basket_encoded = basket_Sweden.applymap(hot_encode) 
basket_Sweden = basket_encoded

# %%
basket_France.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# 536852                               0                                0
# 536974                               0                                0
# 537065                               0                                0
# 537463                               0                                0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                   0
# ...

# %% [markdown]
# ## Building the models and analyzing the results

# %%
# Building the model
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True)

# Collecting the inferred rules in a dataframe
rules = association_rules(frq_items, metric='lift', min_threshold=1)
rules = rules.sort_values(['confidence', 'lift'], ascending=[False, False])
rules.head()
# Out:
# c:\Users\hydon\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                            antecedents  \
# 45                        (JUMBO BAG WOODLAND ANIMALS)
# 259  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 271  (PLASTERS IN TIN WOODLAND ANIMALS, RED TOADSTO...
# 302  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 300  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
#
#                          consequents  antecedent support  consequent support  \
# 45                         (POSTAGE)            0.076531            0.765306
# 259                        (POSTAGE)            0.051020            0.765306
# 271                        (POSTAGE)            0.053571            0.765306
# ...

# %% [markdown]
# From the above output, it can be seen that paper cups and paper and plates are bought together in France. This is because the French have a culture of having a get-together with their friends and family atleast once a week. Also, since the French government has banned the use of plastic in the country, the people have to purchase the paper-based alternatives.

# %% [markdown]
# # Example 3

# %% [markdown]
# https://hands-on.cloud/apriori-algorithm-python-implementation/

# %%
# dataset
data = pd.read_csv("../datasets/Market_Basket_Optimisation.csv")
# printing the shape of the dataset
data.shape
# Out:
# (7500, 20)

# %%
data.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# ...

# %% [markdown]
# ## Top 10 most frequent items

# %%
transaction = []
for i in range(0, data.shape[0]):
    for j in range(0, data.shape[1]):
        transaction.append(data.values[i, j])
transaction = np.array(transaction)
#  Transform Them a Pandas DataFrame
df = pd.DataFrame(transaction, columns=["items"]) 
df.head()
# Out:
#        items
# 0    burgers
# 1  meatballs
# 2       eggs
# 3        nan
# 4        nan

# %%
df.shape
# Out:
# (150000, 1)

# %%
# Put 1 to Each Item For Making Countable Table, to be able to perform Group By
df['incident_count'] = 1
#  Delete NaN Items from Dataset
indexNames = df[df['items'] == 'nan'].index
df = df.drop(indexNames)
df.head()
# Out:
#         items  incident_count
# 0     burgers               1
# 1   meatballs               1
# 2        eggs               1
# 20    chutney               1
# 40     turkey               1

# %%
df.shape
# Out:
# (29343, 2)

# %%
df_table = df.groupby('items').sum().sort_values('incident_count', ascending=False).reset_index()
df_table
# Out:
#              items  incident_count
# 0    mineral water            1787
# 1             eggs            1348
# 2        spaghetti            1306
# 3     french fries            1282
# 4        chocolate            1230
# ..             ...             ...
# 115        bramble              14
# 116          cream               7
# 117        napkins               5
# 118    water spray               3
# 119      asparagus               1
#
# [120 rows x 2 columns]

# %%
df_table.head(10).style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_c792e_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c792e_row1_col1 {
#   background-color: #4eb264;
#   color: #f1f1f1;
# }
# #T_c792e_row2_col1 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_c792e_row3_col1 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_c792e_row4_col1 {
#   background-color: #7ac77b;
#   color: #000000;
# }
# #T_c792e_row5_col1 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_c792e_row6_col1 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_c792e_row7_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_c792e_row8_col1, #T_c792e_row9_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_c792e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c792e_level0_col0" class="col_heading level0 col0" >items</th>
# ...

# %%
# importing required module
import plotly.express as px
# to have a same origin
df_table["all"] = "all" 
# creating tree map using plotly
fig = px.treemap(df_table.head(30), path=['all', "items"], values='incident_count',
                  color=df_table["incident_count"].head(30), hover_data=['items'],
                  color_continuous_scale='Greens',
                )
# ploting the treemap
fig.show()
# Out:
# c:\Users\hydon\anaconda3\Lib\site-packages\plotly\express\imshow_utils.py:24: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# c:\Users\hydon\anaconda3\Lib\site-packages\plotly\io\_renderers.py:395: DeprecationWarning:
#
# distutils Version classes are deprecated. Use packaging.version instead.
#
# ...

# %% [markdown]
# Data Pre-processing
#
#
# * True – the transaction contains the item
# * False – transaction does not contain the item

# %%
transaction
# Out:
# array(['burgers', 'meatballs', 'eggs', ..., 'nan', 'nan', 'nan'],
#       dtype='<U32')

# %%
len(transaction)
# Out:
# 150000

# %%
# importing the required module
from mlxtend.preprocessing import TransactionEncoder
# initializing the transactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transaction).transform(transaction)
dataset = pd.DataFrame(te_ary, columns=te.columns_)
# dataset after encoded
dataset
# Out:
#                    &      a      b      c      d      e      f      g      h  \
# 0       False  False  False   True  False  False   True  False   True  False
# 1       False  False   True   True  False  False   True  False  False  False
# 2       False  False  False  False  False  False   True  False   True  False
# 3       False  False   True  False  False  False  False  False  False  False
# 4       False  False   True  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 149995  False  False   True  False  False  False  False  False  False  False
# 149996  False  False   True  False  False  False  False  False  False  False
# 149997  False  False   True  False  False  False  False  False  False  False
# 149998  False  False   True  False  False  False  False  False  False  False
# 149999  False  False   True  False  False  False  False  False  False  False
#
# ...

# %% [markdown]
# We have 121 columns/features at the moment. Extracting the most frequent itemsets from 121 features would be compelling. So, we will start with the Top 50 items.

# %%
first50 = df_table['items'].head(50).values
dataset = dataset.loc[:, first50]
dataset
# Out:
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# Cell In[43], line 2
#
#       1 first50 = df_table['items'].head(50).values
#
# ----> 2 dataset = dataset.loc[:, first50]
#
#       3 dataset
#
#
#
# File c:\Users\hydon\anaconda3\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#
#    1065     if self._is_scalar_access(key):
#
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
#
# -> 1067     return self._getitem_tuple(key)
#
#    1068 else:
#
#    1069     # we by definition only have the 0th axis
#
#    1070     axis = self.axis or 0
#
#
#
# File c:\Users\hydon\anaconda3\Lib\site-packages\pandas\core\indexing.py:1256, in _LocIndexer._getitem_tuple(self, tup)
#
#    1253 if self._multi_take_opportunity(tup):
#
#    1254     return self._multi_take(tup)
#
# -> 1256 return self._getitem_tuple_same_dim(tup)
#
#
# ...
